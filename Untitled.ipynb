# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x = np.random.normal(loc =0, scale =1, size =1000)
plt.hist(x, bins = 30, density = True)
# Out:
# (array([0.00988701, 0.        , 0.02966103, 0.03954804, 0.04943505,
#         0.03954804, 0.09392659, 0.14830515, 0.19279669, 0.12853113,
#         0.24223174, 0.32132782, 0.38064988, 0.42514142, 0.38559338,
#         0.35593235, 0.38064988, 0.33121483, 0.25706226, 0.29166679,
#         0.18785319, 0.22740123, 0.14336164, 0.1038136 , 0.06426556,
#         0.04449154, 0.01483051, 0.02471752, 0.01977402, 0.00988701]),
#  array([-3.05905123, -2.8567656 , -2.65447997, -2.45219434, -2.24990872,
#         -2.04762309, -1.84533746, -1.64305183, -1.4407662 , -1.23848057,
#         -1.03619494, -0.83390931, -0.63162368, -0.42933806, -0.22705243,
#         -0.0247668 ,  0.17751883,  0.37980446,  0.58209009,  0.78437572,
#          0.98666135,  1.18894697,  1.3912326 ,  1.59351823,  1.79580386,
#          1.99808949,  2.20037512,  2.40266075,  2.60494638,  2.80723201,
#          3.00951763]),
#  <BarContainer object of 30 artists>)

# %%
df2 = np.random.binomial(n= 10, p = 0.6, size =5)
df2
# Out:
# array([7, 7, 4, 8, 7])

# %%
df1 = np.arange(5,15,2)
df1
# Out:
# array([ 5,  7,  9, 11, 13])

# %%
y = np.arange(25)
file = y[y>20]
print(file)
# Out:
# [21 22 23 24]

# %%
m = np.extract(y,y>20)
print(m)
# Out:
# [False False False False False False False False False False False False
#  False False False False False False False False  True  True  True  True]

# %%
size = [30,40.,25,60]
labels = ['python', 'c++', 'java', 'R']
plt.pie(size , labels = labels, autopct='%1.1f%%')
plt.show()

# %%
catagories = ['A','B', 'C','D']
values = [35,49, 10,20]
plt.bar(catagories, values)
plt.title('First Bar Graph')
plt.show()
